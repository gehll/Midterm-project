# %%
import requests
import pandas as pd
from transports import transports

# %%
# Try to get data from API
res = requests.get("http://127.0.0.1:8000/collection/geo_transports").json()

# %%
res[0]['Lines']
# Out:
# list

# %%
# Try to get from geo_transports, data about Tramvia
tramvia = requests.get('http://127.0.0.1:8000/transport_type/Bus').json()
tramvia
# Out:
# 3152

# %%
# Plot barcelona maps with some markers
from folium import Marker, Map
barna_coords = [41.346176, 2.168365]

tooltip = "City name"
barna_marker = Marker(barna_coords, popup="<i>Barcelona</i>", tooltip=tooltip)
mapa_barna = Map(location=barna_coords, zoom_start=10)
mapa_barna.add_child(barna_marker)
mapa_barna
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f886de5bc8f8542706a75e78cca16c9b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f886de5bc8f8542706a75e78cca16c9b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f886de5bc8f8542706a75e78cca16c9b = L.map(
#                 &quot;map_f886de5bc8f8542706a75e78cca16c9b&quot;,
#                 {
#                     center: [41.346176, 2.168365],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_43a350a356c7ff38d87fb8fb51ed0033 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f886de5bc8f8542706a75e78cca16c9b);
#
#
#             var marker_7d2072e76077335f9cde3ad234ed8cd1 = L.marker(
#                 [41.346176, 2.168365],
#                 {}
#             ).addTo(map_f886de5bc8f8542706a75e78cca16c9b);
#
#
#         var popup_bab7f9755af65dd652803e7ca10bf673 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_76d3ce544b5b560c3fb9c03b9833b5be = $(`&lt;div id=&quot;html_76d3ce544b5b560c3fb9c03b9833b5be&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;Barcelona&lt;/i&gt;&lt;/div&gt;`)[0];
#                 popup_bab7f9755af65dd652803e7ca10bf673.setContent(html_76d3ce544b5b560c3fb9c03b9833b5be);
#
#
#
#         marker_7d2072e76077335f9cde3ad234ed8cd1.bindPopup(popup_bab7f9755af65dd652803e7ca10bf673)
#         ;
#
#
#
#
#             marker_7d2072e76077335f9cde3ad234ed8cd1.bindTooltip(
#                 `&lt;div&gt;
#                      City name
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
rawData_params = {
    "limit":1,
    "rawData":0
}

rawData = []
for key in transports.keys():
    rawData.append(requests.get(f'http://127.0.0.1:8000/sample/{key}', params=rawData_params).json()[0])
    
raw_df = pd.DataFrame(rawData)

# %%
raw_df
# Out:
#                                      _id       Code         Transport  \
# 0   {'$oid': '63721ab0b491fd376e9e4f2b'}    0  K014      Day bus stop
# 1   {'$oid': '63721ab0b491fd376e9e4f68'}   61  K016  Airport bus stop
# 2   {'$oid': '63721ab0b491fd376e9e5071'}  326  K017       Bus station
# 3   {'$oid': '63721ab0b491fd376e9e5b85'}    0  K001       Underground
# 4   {'$oid': '63721ab0b491fd376e9e5b8e'}    9  K002     Railway (FGC)
# 5   {'$oid': '63721ab0b491fd376e9e5bac'}   39  K003             RENFE
# 6   {'$oid': '63721ab0b491fd376e9e5bc5'}   64  K004     Airport train
# 7   {'$oid': '63721ab0b491fd376e9e5ba2'}   29  K008  Maritime station
# 8   {'$oid': '63721ab0b491fd376e9e5c36'}  177  K009         Funicular
# 9   {'$oid': '63721ab0b491fd376e9e5be5'}   96  K010          Cableway
# 10  {'$oid': '63721ab0b491fd376e9e5b94'}   15  K011              Tram
#
#    Longitude   Latitude                                            Station  \
# 0   2.171619  41.413744                                         BUS -192--
# 1   2.170821  41.387362                                      AEROBUS -A2--
# 2   2.139355  41.379822                Estació d'Autobusos Barcelona Sants
# 3    2.11937  41.399203  FGC (L6) - REINA ELISENDA (Sortida Duquesa d'O...
# 4   2.158326  41.392331                   FGC - PROVENÇA (C. de Provença)-
# 5   2.181768  41.496321                         RENFE - MONTCADA-RIPOLLET-
# 6   2.189397  41.410259                              Tren AEROPORT - CLOT-
# 7   2.182868  41.370929                    Estació Marítima INTERNACIONAL-
# 8   2.111267  41.409124                  Funicular VALLVIDRERA - inferior-
# 9   2.180119  41.372103                  Transbordador del Port - Jaume I-
# 10  2.098896  41.376486                TRAMVIA (T1,T2,T3) - CA N'OLIVERES-
#
#                            District  \
# 0        {'Name': 'Horta-Guinardó'}
# 1              {'Name': 'Eixample'}
# 2        {'Name': 'Sants-Montjuïc'}
# 3   {'Name': 'Sarrià-Sant Gervasi'}
# 4              {'Name': 'Eixample'}
# 5                                {}
# 6            {'Name': 'Sant Martí'}
# 7                                {}
# 8   {'Name': 'Sarrià-Sant Gervasi'}
# 9          {'Name': 'Ciutat Vella'}
# 10                               {}
#
#                                    Neighborhood  \
# 0                       {'Name': 'el Guinardó'}
# 1            {'Name': 'la Dreta de l'Eixample'}
# 2                       {'Name': 'Hostafrancs'}
# 3                            {'Name': 'Sarrià'}
# 4   {'Name': 'l'Antiga Esquerra de l'Eixample'}
# 5                                            {}
# 6                           {'Name': 'el Clot'}
# 7                                            {}
# 8                            {'Name': 'Sarrià'}
# 9                          {'Name': 'el Raval'}
# 10                                           {}
#
#                                              Location             Lines
# 0   {'type': 'Point', 'coordinates': [2.171619, 41...             [192]
# 1   {'type': 'Point', 'coordinates': [2.170821, 41...              [A2]
# 2   {'type': 'Point', 'coordinates': [2.139355, 41...       Bus station
# 3   {'type': 'Point', 'coordinates': [2.11937, 41....              [L6]
# 4   {'type': 'Point', 'coordinates': [2.158326, 41...               FGC
# 5   {'type': 'Point', 'coordinates': [2.181768, 41...             RENFE
# 6   {'type': 'Point', 'coordinates': [2.189397, 41...     Airport train
# 7   {'type': 'Point', 'coordinates': [2.182868, 41...  Maritime station
# 8   {'type': 'Point', 'coordinates': [2.111267, 41...         Funicular
# 9   {'type': 'Point', 'coordinates': [2.180119, 41...          Cableway
# 10  {'type': 'Point', 'coordinates': [2.098896, 41...      [T1, T2, T3]
